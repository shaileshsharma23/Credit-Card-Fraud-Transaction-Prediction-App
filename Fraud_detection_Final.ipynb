# %% [markdown]
# #Importing the Required Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/creditcard.csv")

# %%
pd.options.display.max_columns = None

# %%
# Display top 5 rows
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
# Display last 5 rows
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %%
# Get information of our dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# #Data Preprocessing

# %%
# Check null values in the dataset
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Droping the null values
data.dropna(axis=1,inplace=True)

# %%
data.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
# Removing the duplicates value
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.shape
# Out:
# (283726, 31)

# %% [markdown]
# Applying the Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler  # we have applied this to make the data more standarized

# %%
sc = StandardScaler()
data['Amount'] = sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
# Check duplicate values in the dataset
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (283726, 31)

# %%
for i in data.columns:
  sns.boxplot(x= data[i])
  plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# We figuring the spread of the data
data.hist(figsize =  (30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f61368e9a00>,
# ...
#       dtype=object)

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
df1=pd.Series(data[data['Class']==1]['Amount'])
df2=pd.Series(data[data['Class']==0]['Amount'])
df3=df2-df1

# %%
data.shape
# Out:
# (283726, 31)

# %%
#df = pd.DataFrame({'Fraud': df1,'Not_Fraud': df2}, index=data.index)
lines = df1.plot.line()

# %%
lines = df2.plot.line()

# %%
df4=pd.Series(data[data['Class']==1]['Time'])
df5=pd.Series(data[data['Class']==0]['Time'])
df6=df5-df4

# %%
lines = df4.plot.line()

# %%
lines = df5.plot.line()

# %% [markdown]
# # corelation_matrix

# %%
data.corr()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# V5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# V6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# V7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# V8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# V9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# V10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
data1=data.iloc[:15,:32]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data1.corr(),cmap="YlGnBu", annot=True)

# %%
y.hist(figsize =  (30,30))

# %%
# Data is imbalanced,further so we are making it balanced.

# %% [markdown]
# # Train_test split for model building

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.7,random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((198608, 30), (198608,), (85118, 30), (85118,))

# %%
y_train.value_counts()
# Out:
# 0    198264
# 1       344
# Name: Class, dtype: int64

# %% [markdown]
# # Random Forest

# %%
# because inbalance datasets are not heavy impact ensembling technique where decision tree are actually used.

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# # Under_Sampling

# %%
# !pip install imblearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from imblearn.under_sampling import NearMiss

# %%
# Implementing Undersampling for Handling Imbalanced 
nm = NearMiss()
X_train_us,y_train_us=nm.fit_resample(X_train,y_train)

# %%
from collections import Counter
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_us)))
# Out:
# The number of classes before fitCounter({0: 198264, 1: 344})
# The number of classes after fitCounter({0: 344, 1: 344})

# %% [markdown]
# Applying Random forest

# %%
rf.fit(X_train_us,y_train_us)
# Out:
# RandomForestClassifier()

# %%
y_pred_us = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_us))
print(accuracy_score(y_test,y_pred_us))
print(classification_report(y_test,y_pred_us))
# Out:
# [[79759  5230]
#  [    8   121]]
# 0.9384618999506568
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     84989
#            1       0.02      0.94      0.04       129
#
#     accuracy                           0.94     85118
#    macro avg       0.51      0.94      0.51     85118
# weighted avg       1.00      0.94      0.97     85118

# %%
list1 = []
for i in range(1,85119):
  list1.append(i)

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_us, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %% [markdown]
# # Over_sampling

# %%
from imblearn.over_sampling import RandomOverSampler

os = RandomOverSampler()
X_train_os, y_train_os = os.fit_resample(X_train, y_train)
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_os)))
# Out:
# The number of classes before fitCounter({0: 198264, 1: 344})
# The number of classes after fitCounter({0: 198264, 1: 198264})

# %%
rf.fit(X_train_os,y_train_os)
y_pred_os = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_os))
print(accuracy_score(y_test,y_pred_os))
print(classification_report(y_test,y_pred_os))
# Out:
# [[84981     8]
#  [   32    97]]
# 0.999530064146244
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84989
#            1       0.92      0.75      0.83       129
#
#     accuracy                           1.00     85118
#    macro avg       0.96      0.88      0.91     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_os, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %% [markdown]
# # Smote

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 157273  109809.0  1.952343 -1.154171 -0.468894 -0.730378 -0.941048 -0.196502
# 85720    60906.0  0.904494 -0.764023 -0.534697  0.350082  1.420277  4.058196
# 197131  131862.0  1.996578  0.426378 -2.301651  1.379143  0.955115 -0.688165
# 58983    48633.0  1.279970 -0.266108 -0.992069 -0.285321  1.883019  3.657542
# 191505  129283.0  1.877653 -0.264576 -0.488413  1.200438 -0.263572 -0.128477
# ...          ...       ...       ...       ...       ...       ...       ...
# 212292  138799.0 -1.094880 -0.384965 -0.499587 -1.696169 -0.869945 -0.931127
# 86612    61311.0  1.173371  0.269374  0.722657  0.690524 -0.477254 -0.805137
# 123052   76790.0 -2.345867 -1.697368  1.474245  1.014289 -0.000236 -0.722979
# 152906   97563.0  2.024540 -0.238464 -1.054008  0.309823 -0.003132 -0.416991
# 118419   75072.0  0.792596 -1.000858  0.911243  0.008789 -0.523715  1.978568
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
X_train_s, y_train_s = sm.fit_resample(X_train, y_train)
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_s)))
# Out:
# The number of classes before fitCounter({0: 198264, 1: 344})
# The number of classes after fitCounter({0: 198264, 1: 198264})

# %%
rf.fit(X_train_s,y_train_s)
y_pred_s = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_s))
print(accuracy_score(y_test,y_pred_s))
print(classification_report(y_test,y_pred_s))
# Out:
# [[84970    19]
#  [   26   103]]
# 0.9994713221645245
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84989
#            1       0.84      0.80      0.82       129
#
#     accuracy                           1.00     85118
#    macro avg       0.92      0.90      0.91     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_s, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %%
import pickle

# %%
pickle.dump(rf,open('trained_card.sav','wb'))
